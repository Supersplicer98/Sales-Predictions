# %% [markdown]
# <a href="https://colab.research.google.com/github/Supersplicer98/Sales-Predictions/blob/main/Histogram_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content.drive/')
# Out:
# Mounted at /content.drive/

# %%
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
filename = ('/content/catsvdogs (3).xlsx')
df = pd.read_excel('/content/catsvdogs (3).xlsx')
df
# Out:
#                 Location  ...  Cat Population
# 0                Alabama  ...            1252
# 1                Arizona  ...            1438
# 2               Arkansas  ...             810
# 3             California  ...            7118
# 4               Colorado  ...            1191
# 5            Connecticut  ...             796
# 6               Delaware  ...             187
# 7   District of Columbia  ...              63
# 8                Florida  ...            4375
# 9                Georgia  ...            2162
# 10                 Idaho  ...             393
# 11              Illinois  ...            2453
# 12               Indiana  ...            1912
# 13                  Iowa  ...             805
# 14                Kansas  ...             731
# 15              Kentucky  ...            1349
# 16             Louisiana  ...             877
# 17                 Maine  ...             498
# 18              Maryland  ...            1677
# ...

# %%
df['Percentage of Dog Owners'].head()
# Out:
# 0    44.1
# 1    40.1
# 2    47.9
# 3    32.8
# 4    42.5
# Name: Percentage of Dog Owners, dtype: float64

# %%
df['Percentage of Dog Owners'].hist()

# %%
df['Percentage of Cat Owners'].head()
# Out:
# 0    27.4
# 1    29.6
# 2    30.6
# 3    28.3
# 4    32.3
# Name: Percentage of Cat Owners, dtype: float64

# %%
df['Percentage of Cat Owners'].hist() # Dogs are the popular choice in a majority of households
